# %% [markdown]
# import pandas as pd
#
# data = pd.io.stata.read_stata('AmesHousingGeo.dta')
# data.to_csv('AmesHousingGeo.csv')
#
#
# #This code converts the .dta file to a readable .csv file

# %%
# importing pandas package
import pandas as pd
import matplotlib.pyplot as plt 
# making data frame from csv file
data = pd.read_csv("AmesHousingGeo.csv")
data.head()
# Out:
#    longitude   latitude        pid  order  mssubclass mszoning  lotfrontage  \
# 0 -93.641945  42.063297  528228325   2421         120       RL          NaN
# 1 -93.644920  42.011837  909452102   2227          20       RL          NaN
# 2 -93.665800  42.024124  905453080    242          20       RL         44.0
# 3 -93.687830  42.014550  907405020   1473          20       RL         70.0
# 4 -93.689350  42.016895  907192020   2131          60       RL         68.0
#
#    lotarea street alley  ... poolqc fence miscfeature miscval mosold yrsold  \
# 0     3196   Pave   NaN  ...    NaN   NaN         NaN       0     10   2006
# 1    17871   Pave   NaN  ...    NaN   NaN         NaN       0      6   2007
# 2    17485   Pave   NaN  ...    NaN   NaN         NaN       0      1   2010
# 3     9135   Pave   NaN  ...    NaN   NaN         NaN       0     12   2008
# 4     9543   Pave   NaN  ...    NaN   NaN         NaN       0      2   2007
#
#   saletype salecondition saleprice       _merge
# ...

# %%
x = data.lotarea
y = data.overallcond

plt.title('Lot Area vs Overall Condition')
plt.xlabel('Lot Area')
plt.ylabel('Overall Condition')
plt.plot(x,y)
plt.show()

# %%
x = data.lotarea
y = data.overallcond

plt.title('Lot Area vs Overall Condition')
plt.xlabel('Lot Area')
plt.ylabel('Overall Condition')
plt.plot(x,y)
plt.show()

# %%
x = data.bedroomabvgr
y = data.kitchenabvgr

plt.title('Bedroom vs Kitchen Number')
plt.xlabel('Bedrooms')
plt.ylabel('Kitchens')
plt.plot(x,y)
plt.show()
