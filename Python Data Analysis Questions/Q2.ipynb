# %%
from pandas import read_csv
import matplotlib.pyplot as plt

# %%
plt.style.use('fivethirtyeight')

series = read_csv('ARMA_Data.csv', header=0, index_col=0)
plt.style.use('fivethirtyeight')
series.plot()
pyplot.show()
#This creates a line plot of the series

# %% [markdown]
# # Autocorrelation of A

# %%
plt.style.use('fivethirtyeight')
from statsmodels.graphics import tsaplots

series = read_csv('ARMA_Data.csv')

# Display the autocorrelation plot of your time series
fig = tsaplots.plot_acf(series['A'], lags=40)

# Show plot
plt.show()

# %% [markdown]
# # Autocorrelation of B

# %%
plt.style.use('fivethirtyeight')
from statsmodels.graphics import tsaplots

series = read_csv('ARMA_Data.csv')

# Display the autocorrelation plot of your time series
fig = tsaplots.plot_acf(series['B'], lags=40)

# Show plot
plt.show()

# %% [markdown]
# # Partial Autocorrelation of A

# %%
plt.style.use('fivethirtyeight')
from statsmodels.graphics import tsaplots

series = read_csv('ARMA_Data.csv')

# Display the partial autocorrelation plot of your time series
fig = tsaplots.plot_pacf(series['A'], lags=40)

# Show plot
plt.show()

# %% [markdown]
# # Partial Autocorrelation of B

# %%
plt.style.use('fivethirtyeight')
from statsmodels.graphics import tsaplots

series = read_csv('ARMA_Data.csv')

# Display the partial autocorrelation plot of your time series
fig = tsaplots.plot_pacf(series['B'], lags=40)

# Show plot
plt.show()
